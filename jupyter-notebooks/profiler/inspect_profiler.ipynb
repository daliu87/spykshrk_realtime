# %%
import pstats
import os.path

# %%
prof_dir = '/home/daliu/output/'
filename = 'test_animal01pstats'
p = pstats.Stats(os.path.join(prof_dir, filename))

# %%
p.sort_stats('ncalls')
p.print_stats()
# Out:
# Thu May 25 19:53:58 2017    /home/daliu/output/test_animal01pstats
#
#          10919099 function calls (10919164 primitive calls) in 22.004 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    904086    0.783    0.000    1.255    0.000 /home/daliu/anaconda3/lib/python3.6/threading.py:239(Condition.__enter__)
#    904086    0.778    0.000    1.106    0.000 /home/daliu/anaconda3/lib/python3.6/threading.py:242(Condition.__exit__)
#    904084    1.700    0.000    4.061    0.000 /home/daliu/anaconda3/lib/python3.6/threading.py:533(Event.wait)
#    452009    1.180    0.000   22.198    0.000 /home/daliu/Src/spykshrk_realtime/spykshrk/realtime/simulator/sim_databuffer.py:22(SimDataBuffer.__call__)
#    449990    0.532    0.000    0.722    0.000 /home/daliu/anaconda3/lib/python3.6/types.py:135(DynamicClassAttribute.__get__)
# ...
