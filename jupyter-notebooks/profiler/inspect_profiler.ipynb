# %%
import pstats
import os.path

# %%
prof_dir = '/home/daliu/output/'
prof_dir = '/opt/data36/daliu/realtime/spykshrk'
filename = 'test_animal.thread.01.pstats'
p = pstats.Stats(os.path.join(prof_dir, filename))

# %%
p.strip_dirs()
p.sort_stats('cumtime')
p.print_stats()
# Out:
# Tue May 30 16:12:18 2017    /opt/data36/daliu/realtime/spykshrk/test_animal.thread.01.pstats
#
#          19092459 function calls (18681553 primitive calls) in 50.984 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    3.566    3.566   50.984   50.984 simulator_process.py:172(run)
#    449981   25.621    0.000   25.621    0.000 {method 'send' of 'mpi4py.MPI.Comm' objects}
#    452009    1.042    0.000   17.495    0.000 sim_databuffer.py:22(__call__)
#    452010    0.219    0.000   15.921    0.000 {built-in method builtins.next}
#    449915    5.490    0.000   12.515    0.000 nspike_data.py:468(__call__)
#    181348    0.137    0.000    5.394    0.000 generic.py:2910(values)
#    181348    0.475    0.000    5.258    0.000 generic.py:2868(as_matrix)
#    904083    1.633    0.000    3.689    0.000 threading.py:531(wait)
#    181348    0.329    0.000    3.402    0.000 internals.py:3391(as_matrix)
#      2095    0.008    0.000    3.187    0.002 nspike_data.py:976(__call__)
#       700    0.056    0.000    3.175    0.005 nspike_data.py:921(__call__)
#    183442    0.199    0.000    1.739    0.000 internals.py:154(get_values)
#     14658    0.047    0.000    1.704    0.000 series.py:600(__getitem__)
#     12564    0.062    0.000    1.558    0.000 multi.py:681(get_value)
#    184840    0.207    0.000    1.533    0.000 common.py:54(is_object_dtype)
#    182047    0.207    0.000    1.385    0.000 generic.py:2795(_consolidate_inplace)
#      4188    0.061    0.000    1.358    0.000 multi.py:689(_try_mi)
#    181348    0.601    0.000    1.347    0.000 internals.py:2829(_is_single_block)
#    189747    1.012    0.000    1.287    0.000 common.py:357(_get_dtype_type)
#    631263    1.048    0.000    1.204    0.000 base.py:1406(__getitem__)
#    182746    0.291    0.000    1.181    0.000 generic.py:2785(_protect_consolidate)
#    904083    0.473    0.000    0.910    0.000 threading.py:237(__enter__)
#      2097    0.015    0.000    0.828    0.000 frame.py:2035(__getitem__)
#    182047    0.312    0.000    0.826    0.000 generic.py:2798(f)
# 1649203/1238998    0.463    0.000    0.806    0.000 {built-in method builtins.len}
#    904083    0.462    0.000    0.601    0.000 threading.py:240(__exit__)
#      4887    0.038    0.000    0.593    0.000 multi.py:1075(__getitem__)
#      5586    0.033    0.000    0.553    0.000 multi.py:77(__new__)
#         1    0.000    0.000    0.546    0.546 threading.py:261(wait)
#         4    0.546    0.136    0.546    0.136 {method 'acquire' of '_thread.lock' objects}
#    449981    0.389    0.000    0.509    0.000 types.py:130(__get__)
#   1910445    0.466    0.000    0.504    0.000 {built-in method builtins.isinstance}
#    449914    0.470    0.000    0.470    0.000 datatypes.py:19(__init__)
#      7680    0.058    0.000    0.463    0.000 series.py:135(__init__)
#      4887    0.011    0.000    0.440    0.000 indexing.py:1923(maybe_droplevels)
#    904083    0.437    0.000    0.437    0.000 {method '__enter__' of '_thread.lock' objects}
#    182047    0.126    0.000    0.431    0.000 internals.py:2951(__len__)
#      4887    0.100    0.000    0.428    0.000 multi.py:1248(droplevel)
#    192523    0.370    0.000    0.425    0.000 generic.py:2746(__setattr__)
#       699    0.004    0.000    0.365    0.001 frame.py:2078(_getitem_array)
#      2793    0.013    0.000    0.356    0.000 frame.py:654(iterrows)
#    452008    0.355    0.000    0.355    0.000 {built-in method builtins.min}
#       699    0.007    0.000    0.323    0.000 generic.py:1650(take)
#       699    0.020    0.000    0.320    0.000 frame.py:2100(_getitem_multilevel)
#       699    0.009    0.000    0.280    0.000 internals.py:3943(take)
#      5586    0.030    0.000    0.245    0.000 multi.py:157(_set_levels)
#     16758    0.044    0.000    0.229    0.000 base.py:371(_shallow_copy)
#      6285    0.015    0.000    0.213    0.000 multi.py:1609(get_loc)
#      2798    0.048    0.000    0.211    0.000 algorithms.py:1010(take_nd)
#       699    0.002    0.000    0.209    0.000 base.py:1345(__iter__)
#       700    0.014    0.000    0.207    0.000 multi.py:611(values)
#     17457    0.019    0.000    0.188    0.000 multi.py:171(<genexpr>)
#    456895    0.187    0.000    0.187    0.000 {method 'index' of 'list' objects}
#       699    0.009    0.000    0.179    0.000 ops.py:803(wrapper)
#    182047    0.114    0.000    0.176    0.000 internals.py:3513(consolidate)
#    654303    0.175    0.000    0.175    0.000 {pandas.lib.isscalar}
#      6285    0.098    0.000    0.173    0.000 multi.py:1828(_get_level_indexer)
#      4887    0.028    0.000    0.169    0.000 base.py:1506(take)
#      5586    0.047    0.000    0.142    0.000 multi.py:484(_set_names)
#    904083    0.139    0.000    0.139    0.000 {method '__exit__' of '_thread.lock' objects}
#      1399    0.007    0.000    0.130    0.000 internals.py:2745(__init__)
#    209290    0.099    0.000    0.129    0.000 base.py:491(__len__)
#      5586    0.028    0.000    0.125    0.000 multi.py:266(_set_labels)
#       699    0.004    0.000    0.124    0.000 internals.py:3813(reindex_indexer)
#    449981    0.119    0.000    0.119    0.000 enum.py:527(value)
#      6981    0.030    0.000    0.116    0.000 series.py:2817(_sanitize_array)
#       699    0.006    0.000    0.110    0.000 multi.py:1099(take)
#      1398    0.007    0.000    0.109    0.000 frame.py:252(__init__)
#      7680    0.024    0.000    0.104    0.000 internals.py:4031(__init__)
#     37699    0.041    0.000    0.100    0.000 {pandas.lib.values_from_object}
#       699    0.005    0.000    0.095    0.000 frame.py:404(_init_ndarray)
#    183450    0.071    0.000    0.093    0.000 internals.py:2790(ndim)
#     10481    0.010    0.000    0.092    0.000 {method 'any' of 'numpy.ndarray' objects}
#     16760    0.050    0.000    0.088    0.000 base.py:334(_simple_new)
#     25833    0.067    0.000    0.086    0.000 multi.py:481(_get_names)
#     17457    0.021    0.000    0.086    0.000 multi.py:276(<genexpr>)
#      5587    0.013    0.000    0.086    0.000 {built-in method builtins.sorted}
#    375286    0.082    0.000    0.082    0.000 internals.py:179(mgr_locs)
#     10481    0.006    0.000    0.082    0.000 _methods.py:37(_any)
#      1400    0.026    0.000    0.079    0.000 internals.py:2841(_rebuild_blknos_and_blklocs)
#     42610    0.061    0.000    0.078    0.000 base.py:715(__getitem__)
#      2094    0.011    0.000    0.078    0.000 base.py:2146(get_value)
#     27976    0.032    0.000    0.078    0.000 dtypes.py:74(is_dtype)
#     10482    0.076    0.000    0.076    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     16760    0.059    0.000    0.076    0.000 base.py:606(_get_attributes_dict)
#       699    0.004    0.000    0.074    0.000 internals.py:4236(create_block_manager_from_blocks)
#      9079    0.028    0.000    0.074    0.000 internals.py:2649(make_block)
#      9774    0.005    0.000    0.072    0.000 multi.py:1273(<genexpr>)
#      2798    0.014    0.000    0.071    0.000 cast.py:227(_maybe_promote)
#      4887    0.022    0.000    0.067    0.000 multi.py:586(_get_level_number)
#     16056    0.009    0.000    0.066    0.000 series.py:391(get_values)
#     18169    0.025    0.000    0.066    0.000 multi.py:478(__len__)
#      9792    0.006    0.000    0.064    0.000 common.py:69(is_datetimetz)
#     11871    0.010    0.000    0.062    0.000 base.py:1014(rename)
#      7680    0.024    0.000    0.061    0.000 series.py:286(_set_axis)
#     14658    0.054    0.000    0.060    0.000 {method 'get_value' of 'pandas.index.IndexEngine' objects}
#     16056    0.028    0.000    0.057    0.000 internals.py:4177(get_values)
#    185543    0.057    0.000    0.057    0.000 internals.py:2862(_get_items)
#    184844    0.056    0.000    0.056    0.000 internals.py:3249(is_consolidated)
#       699    0.001    0.000    0.056    0.000 frame.py:2061(_getitem_column)
#     70556    0.050    0.000    0.055    0.000 {built-in method builtins.getattr}
#       699    0.003    0.000    0.054    0.000 generic.py:1381(_get_item_cache)
#      2097    0.003    0.000    0.054    0.000 multi.py:1038(__contains__)
#      4898    0.012    0.000    0.052    0.000 internals.py:2786(shape)
#     90143    0.050    0.000    0.052    0.000 {built-in method builtins.hasattr}
#     11871    0.018    0.000    0.052    0.000 base.py:955(set_names)
#    217007    0.052    0.000    0.052    0.000 {built-in method builtins.issubclass}
#       699    0.013    0.000    0.051    0.000 ops.py:749(na_op)
#     11871    0.013    0.000    0.051    0.000 base.py:3673(_ensure_frozen)
#       699    0.002    0.000    0.051    0.000 internals.py:3848(<listcomp>)
#     65640    0.050    0.000    0.050    0.000 {method 'view' of 'numpy.ndarray' objects}
#     13988    0.007    0.000    0.049    0.000 common.py:89(is_datetime64tz_dtype)
#       699    0.003    0.000    0.049    0.000 internals.py:1001(take_nd)
#      6981    0.008    0.000    0.046    0.000 series.py:2834(_try_cast)
#      2094    0.010    0.000    0.045    0.000 series.py:1114(tolist)
#      6285    0.011    0.000    0.044    0.000 function.py:37(__call__)
# 32828/32129    0.038    0.000    0.044    0.000 {built-in method numpy.core.multiarray.array}
#      9079    0.021    0.000    0.043    0.000 internals.py:96(__init__)
#     14694    0.005    0.000    0.040    0.000 internals.py:2788(<genexpr>)
#     25841    0.018    0.000    0.040    0.000 base.py:522(values)
#     11192    0.007    0.000    0.039    0.000 common.py:102(is_categorical_dtype)
#     12567    0.024    0.000    0.039    0.000 series.py:322(name)
#     25863    0.016    0.000    0.038    0.000 generic.py:7(_check)
#      7683    0.010    0.000    0.036    0.000 base.py:2104(get_loc)
#      2094    0.002    0.000    0.035    0.000 series.py:395(asobject)
#      6285    0.010    0.000    0.033    0.000 validators.py:129(validate_kwargs)
#      2094    0.003    0.000    0.033    0.000 internals.py:4181(asobject)
#     27930    0.018    0.000    0.032    0.000 inference.py:53(is_list_like)
#      5586    0.011    0.000    0.030    0.000 common.py:194(is_bool_indexer)
#      4188    0.011    0.000    0.030    0.000 base.py:1339(is_all_dates)
#      1399    0.006    0.000    0.030    0.000 internals.py:2966(_verify_integrity)
#     13970    0.006    0.000    0.029    0.000 <frozen importlib._bootstrap>:996(_handle_fromlist)
#     11871    0.009    0.000    0.028    0.000 cast.py:439(_coerce_indexer_dtype)
#      1398    0.003    0.000    0.027    0.000 indexing.py:1769(convert_to_index_sliceable)
#      8384    0.010    0.000    0.025    0.000 numeric.py:414(asarray)
#       699    0.002    0.000    0.025    0.000 frame.py:2393(_box_item_values)
#      1398    0.004    0.000    0.024    0.000 common.py:320(_coerce_to_dtype)
#      6285    0.021    0.000    0.023    0.000 multi.py:1628(_maybe_to_slice)
#       699    0.002    0.000    0.022    0.000 internals.py:3536(get)
#     11172    0.006    0.000    0.022    0.000 base.py:110(_reset_cache)
#      3497    0.003    0.000    0.021    0.000 common.py:64(is_categorical)
#     16760    0.013    0.000    0.021    0.000 __init__.py:175(iteritems)
#      9078    0.021    0.000    0.021    0.000 generic.py:114(__init__)
#       699    0.002    0.000    0.020    0.000 indexing.py:1806(check_bool_indexer)
#     10473    0.020    0.000    0.020    0.000 {built-in method pandas.algos.ensure_platform_int}
#      2097    0.002    0.000    0.020    0.000 common.py:264(needs_i8_conversion)
#      4887    0.020    0.000    0.020    0.000 multi.py:1093(<listcomp>)
#       699    0.010    0.000    0.019    0.000 indexing.py:1857(maybe_convert_indices)
#     16056    0.008    0.000    0.019    0.000 internals.py:163(to_dense)
#       699    0.001    0.000    0.018    0.000 frame.py:2400(_box_col_values)
#      9078    0.018    0.000    0.018    0.000 generic.py:2730(__getattr__)
#      2796    0.006    0.000    0.018    0.000 dtypes.py:221(construct_from_string)
#       699    0.002    0.000    0.017    0.000 series.py:252(from_array)
#      7680    0.010    0.000    0.017    0.000 series.py:326(name)
#       699    0.001    0.000    0.017    0.000 generic.py:131(_validate_dtype)
#      6285    0.017    0.000    0.017    0.000 validators.py:113(_check_for_invalid_keys)
#      2798    0.007    0.000    0.017    0.000 numeric.py:2576(seterr)
#     23747    0.012    0.000    0.017    0.000 base.py:3637(_ensure_index)
#     16760    0.013    0.000    0.016    0.000 base.py:608(<listcomp>)
#      6282    0.005    0.000    0.016    0.000 series.py:386(_values)
#      5598    0.016    0.000    0.016    0.000 {built-in method numpy.core.multiarray.empty}
#     67026    0.015    0.000    0.015    0.000 multi.py:482(<genexpr>)
#       699    0.005    0.000    0.015    0.000 internals.py:3565(iget)
#       699    0.001    0.000    0.015    0.000 common.py:231(is_datetimelike_v_numeric)
#     17458    0.010    0.000    0.015    0.000 multi.py:1030(nlevels)
#      6984    0.015    0.000    0.015    0.000 {method 'take' of 'numpy.ndarray' objects}
#     78206    0.014    0.000    0.014    0.000 multi.py:154(_get_levels)
#      9079    0.012    0.000    0.014    0.000 internals.py:216(mgr_locs)
#      2097    0.014    0.000    0.014    0.000 {pandas.algos.take_1d_int64_int64}
#       699    0.005    0.000    0.014    0.000 cast.py:765(_possibly_cast_to_datetime)
#     11871    0.005    0.000    0.014    0.000 base.py:778(_shallow_copy)
#      4887    0.005    0.000    0.014    0.000 base.py:1523(_assert_take_fillable)
#      7683    0.014    0.000    0.014    0.000 {method 'get_loc' of 'pandas.index.IndexEngine' objects}
#      6981    0.013    0.000    0.013    0.000 cast.py:660(_possibly_castable)
#      1398    0.003    0.000    0.012    0.000 internals.py:208(make_block_same_class)
#       699    0.007    0.000    0.012    0.000 base.py:1392(__contains__)
#      2097    0.003    0.000    0.012    0.000 multi.py:2051(equals)
#      3495    0.002    0.000    0.012    0.000 common.py:98(is_period_dtype)
#     22346    0.012    0.000    0.012    0.000 base.py:485(_reset_identity)
#     29322    0.012    0.000    0.012    0.000 internals.py:4077(_block)
#      1399    0.002    0.000    0.012    0.000 numeric.py:2967(__enter__)
#      6282    0.007    0.000    0.011    0.000 internals.py:4174(internal_values)
#      2796    0.006    0.000    0.011    0.000 dtypes.py:170(__new__)
# 4894/4892    0.003    0.000    0.011    0.000 base.py:874(_values)
#      2094    0.004    0.000    0.011    0.000 base.py:1131(_convert_scalar_indexer)
#      2094    0.011    0.000    0.011    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      4890    0.003    0.000    0.011    0.000 series.py:333(dtype)
#       699    0.001    0.000    0.010    0.000 common.py:301(is_extension_type)
#      4188    0.010    0.000    0.010    0.000 {pandas.lib.is_datetime_array}
#      1399    0.004    0.000    0.010    0.000 internals.py:3257(_consolidate_check)
#     16755    0.007    0.000    0.010    0.000 common.py:447(_apply_if_callable)
#      3495    0.005    0.000    0.010    0.000 dtypes.py:347(is_dtype)
#      2797    0.002    0.000    0.009    0.000 internals.py:3529(_consolidate_inplace)
#       699    0.001    0.000    0.009    0.000 multi.py:1111(_assert_take_fillable)
#      1399    0.002    0.000    0.009    0.000 numeric.py:2972(__exit__)
#     11871    0.008    0.000    0.009    0.000 base.py:947(_set_names)
#      2795    0.006    0.000    0.009    0.000 base.py:1302(_engine)
#     36327    0.009    0.000    0.009    0.000 multi.py:263(_get_labels)
#      2795    0.002    0.000    0.008    0.000 base.py:1305(<lambda>)
#      5598    0.008    0.000    0.008    0.000 {built-in method pandas.algos.ensure_int64}
#       699    0.001    0.000    0.008    0.000 multi.py:1130(<listcomp>)
#       700    0.008    0.000    0.008    0.000 {pandas.lib.fast_zip}
#      7680    0.005    0.000    0.007    0.000 inference.py:66(is_hashable)
#      4890    0.004    0.000    0.007    0.000 internals.py:4147(dtype)
#     10476    0.004    0.000    0.007    0.000 {built-in method builtins.hash}
#     42610    0.007    0.000    0.007    0.000 {function FrozenList.__getitem__ at 0x7fa79161e400}
#      2798    0.005    0.000    0.007    0.000 algorithms.py:977(_get_take_nd_function)
#      2099    0.002    0.000    0.007    0.000 common.py:188(is_datetime_or_timedelta_dtype)
#     22346    0.007    0.000    0.007    0.000 {built-in method __new__ of type object at 0x7fa79f892360}
#       699    0.007    0.000    0.007    0.000 {pandas.algos.take_2d_axis1_float64_float64}
#         1    0.000    0.000    0.007    0.007 internals.py:4511(_consolidate)
#         1    0.004    0.004    0.007    0.007 internals.py:4528(_merge_blocks)
#      7680    0.006    0.000    0.006    0.000 series.py:312(_set_subtyp)
#      2798    0.006    0.000    0.006    0.000 numeric.py:2676(geterr)
#      1399    0.001    0.000    0.006    0.000 internals.py:3258(<listcomp>)
#      5586    0.004    0.000    0.006    0.000 generic.py:2713(__finalize__)
#     14661    0.005    0.000    0.005    0.000 {method 'pop' of 'list' objects}
#      2094    0.005    0.000    0.005    0.000 {method 'tolist' of 'numpy.generic' objects}
#       699    0.000    0.000    0.005    0.000 series.py:463(__len__)
#      1398    0.001    0.000    0.005    0.000 common.py:59(is_sparse)
#      2796    0.005    0.000    0.005    0.000 {method 'search' of '_sre.SRE_Pattern' objects}
#      3497    0.005    0.000    0.005    0.000 dtypes.py:132(construct_from_string)
#       699    0.001    0.000    0.004    0.000 generic.py:2825(_is_mixed_type)
#     17459    0.004    0.000    0.004    0.000 {built-in method builtins.iter}
#      1403    0.004    0.000    0.004    0.000 internals.py:301(ftype)
#      1398    0.002    0.000    0.004    0.000 generic.py:1503(_set_is_copy)
#     16758    0.004    0.000    0.004    0.000 {method 'update' of 'dict' objects}
#       704    0.001    0.000    0.004    0.000 numeric.py:484(asanyarray)
#      1398    0.001    0.000    0.004    0.000 generic.py:353(_get_axis)
#       699    0.000    0.000    0.004    0.000 series.py:473(__array__)
#     17459    0.004    0.000    0.004    0.000 {method 'items' of 'dict' objects}
#      1404    0.004    0.000    0.004    0.000 {built-in method numpy.core.multiarray.arange}
#      1399    0.002    0.000    0.004    0.000 internals.py:2746(<listcomp>)
#      1399    0.001    0.000    0.003    0.000 {built-in method builtins.sum}
#      6285    0.003    0.000    0.003    0.000 validators.py:31(_check_for_default_values)
#       699    0.001    0.000    0.003    0.000 generic.py:1395(_set_as_cached)
#       699    0.001    0.000    0.003    0.000 generic.py:829(__hash__)
#      1400    0.001    0.000    0.003    0.000 common.py:81(is_datetime64_dtype)
#      5597    0.003    0.000    0.003    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.003    0.003 internals.py:4581(_vstack)
#         1    0.000    0.000    0.003    0.003 shape_base.py:180(vstack)
#      1398    0.001    0.000    0.003    0.000 missing.py:27(isnull)
#         2    0.003    0.001    0.003    0.001 {built-in method numpy.core.multiarray.concatenate}
#     16755    0.003    0.000    0.003    0.000 {built-in method builtins.callable}
#     11172    0.003    0.000    0.003    0.000 {built-in method pandas.algos.ensure_int8}
#       699    0.001    0.000    0.002    0.000 generic.py:357(_get_block_manager_axis)
#      6285    0.002    0.000    0.002    0.000 {method 'copy' of 'dict' objects}
#      2798    0.002    0.000    0.002    0.000 {built-in method numpy.core.umath.seterrobj}
#       699    0.001    0.000    0.002    0.000 frame.py:5463(_prep_ndarray)
#      2800    0.002    0.000    0.002    0.000 {method 'fill' of 'numpy.ndarray' objects}
#      1398    0.002    0.000    0.002    0.000 generic.py:340(_get_axis_name)
#      7002    0.002    0.000    0.002    0.000 internals.py:297(dtype)
#      1398    0.001    0.000    0.002    0.000 missing.py:48(_isnull_new)
#      2802    0.001    0.000    0.002    0.000 internals.py:2968(<genexpr>)
#       699    0.001    0.000    0.002    0.000 generic.py:2827(<lambda>)
#       701    0.002    0.000    0.002    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.002    0.002 base.py:897(argmin)
#      1399    0.002    0.000    0.002    0.000 numeric.py:2963(__init__)
#         1    0.000    0.000    0.002    0.002 nanops.py:470(nanargmin)
#       699    0.002    0.000    0.002    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#      2097    0.001    0.000    0.002    0.000 base.py:465(is_)
#      4887    0.002    0.000    0.002    0.000 {method 'count' of 'list' objects}
#       701    0.001    0.000    0.002    0.000 common.py:135(is_dtype_equal)
#         1    0.000    0.000    0.002    0.002 nanops.py:175(_get_values)
#       699    0.001    0.000    0.002    0.000 frame.py:421(_get_axes)
#       699    0.001    0.000    0.002    0.000 generic.py:327(_get_axis_number)
#       699    0.001    0.000    0.001    0.000 internals.py:3262(is_mixed_type)
#      6282    0.001    0.000    0.001    0.000 internals.py:148(internal_values)
#      5586    0.001    0.000    0.001    0.000 {built-in method builtins.any}
#      5596    0.001    0.000    0.001    0.000 {built-in method numpy.core.umath.geterrobj}
#      4188    0.001    0.000    0.001    0.000 series.py:263(_constructor)
#       701    0.001    0.000    0.001    0.000 common.py:282(is_float_dtype)
#       699    0.001    0.000    0.001    0.000 generic.py:144(_init_mgr)
#       699    0.001    0.000    0.001    0.000 nspike_data.py:274(__init__)
#      4188    0.001    0.000    0.001    0.000 {built-in method pandas.algos.ensure_object}
#         1    0.000    0.000    0.001    0.001 base.py:3492(_evaluate_numeric_binop)
#      2094    0.001    0.000    0.001    0.000 datatypes.py:54(__init__)
#      4893    0.001    0.000    0.001    0.000 {pandas.lib.is_float}
#       701    0.000    0.000    0.001    0.000 common.py:93(is_timedelta64_dtype)
#      4199    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      1402    0.001    0.000    0.001    0.000 common.py:333(_get_dtype)
#         1    0.001    0.001    0.001    0.001 {method 'copy' of 'numpy.ndarray' objects}
#       699    0.001    0.000    0.001    0.000 internals.py:326(iget)
#      1398    0.001    0.000    0.001    0.000 {built-in method pandas.lib.checknull}
#         1    0.001    0.001    0.001    0.001 {built-in method _operator.sub}
#      1398    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#      3492    0.001    0.000    0.001    0.000 multi.py:863(is_all_dates)
#      1403    0.001    0.000    0.001    0.000 internals.py:289(shape)
#      1398    0.001    0.000    0.001    0.000 frame.py:241(_constructor)
#         1    0.000    0.000    0.000    0.000 nanops.py:220(_isfinite)
#      2094    0.000    0.000    0.000    0.000 nspike_data.py:985(<lambda>)
#       699    0.000    0.000    0.000    0.000 base.py:1097(is_unique)
#         1    0.000    0.000    0.000    0.000 __init__.py:1269(info)
#         1    0.000    0.000    0.000    0.000 __init__.py:1392(_log)
#      1399    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#       699    0.000    0.000    0.000    0.000 internals.py:175(fill_value)
#         2    0.000    0.000    0.000    0.000 base.py:142(__new__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1417(handle)
#         1    0.000    0.000    0.000    0.000 __init__.py:1471(callHandlers)
#         2    0.000    0.000    0.000    0.000 __init__.py:842(handle)
#       700    0.000    0.000    0.000    0.000 {pandas.lib.is_integer}
#         2    0.000    0.000    0.000    0.000 __init__.py:968(emit)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.putmask}
#       699    0.000    0.000    0.000    0.000 {built-in method pandas.algos.ensure_int16}
#         1    0.000    0.000    0.000    0.000 base.py:501(__array_wrap__)
#         3    0.000    0.000    0.000    0.000 __init__.py:819(format)
#         3    0.000    0.000    0.000    0.000 __init__.py:554(format)
#         1    0.000    0.000    0.000    0.000 handlers.py:63(emit)
#         2    0.000    0.000    0.000    0.000 numeric.py:28(__new__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1377(makeRecord)
#         1    0.000    0.000    0.000    0.000 base.py:3438(_validate_for_numeric_binop)
#         1    0.000    0.000    0.000    0.000 __init__.py:243(__init__)
#         3    0.000    0.000    0.000    0.000 __init__.py:487(formatTime)
#         2    0.000    0.000    0.000    0.000 __init__.py:957(flush)
#         1    0.000    0.000    0.000    0.000 numeric.py:607(require)
#         1    0.000    0.000    0.000    0.000 handlers.py:177(shouldRollover)
#         1    0.000    0.000    0.000    0.000 nanops.py:610(_maybe_arg_null_out)
#         1    0.000    0.000    0.000    0.000 shape_base.py:230(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1039(emit)
#         1    0.000    0.000    0.000    0.000 multi.py:879(lexsort_depth)
#         5    0.000    0.000    0.000    0.000 shape_base.py:61(atleast_2d)
#         3    0.000    0.000    0.000    0.000 {built-in method time.localtime}
#         1    0.000    0.000    0.000    0.000 internals.py:4542(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'flush' of '_io.TextIOWrapper' objects}
#         2    0.000    0.000    0.000    0.000 common.py:170(is_datetime64_any_dtype)
#         1    0.000    0.000    0.000    0.000 _methods.py:40(_all)
#         1    0.000    0.000    0.000    0.000 __init__.py:1347(findCaller)
#        10    0.000    0.000    0.000    0.000 internals.py:4517(<lambda>)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:828(argsort)
#         2    0.000    0.000    0.000    0.000 copyreg.py:96(_slotnames)
#         1    0.000    0.000    0.000    0.000 multi.py:887(<listcomp>)
#         2    0.000    0.000    0.000    0.000 nanops.py:229(_na_ok_dtype)
#         2    0.000    0.000    0.000    0.000 {pandas.algos.take_1d_object_object}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        10    0.000    0.000    0.000    0.000 internals.py:111(_consolidate_key)
#         1    0.000    0.000    0.000    0.000 nanops.py:233(_view_if_needed)
#         3    0.000    0.000    0.000    0.000 __init__.py:538(formatMessage)
#         1    0.000    0.000    0.000    0.000 __init__.py:149(<lambda>)
#         3    0.000    0.000    0.000    0.000 __init__.py:382(format)
#         4    0.000    0.000    0.000    0.000 __init__.py:806(release)
#         1    0.000    0.000    0.000    0.000 posixpath.py:136(basename)
#         2    0.000    0.000    0.000    0.000 numeric.py:676(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seek' of '_io.TextIOWrapper' objects}
#         3    0.000    0.000    0.000    0.000 __init__.py:532(usesTime)
#         2    0.000    0.000    0.000    0.000 common.py:292(is_bool_dtype)
#         3    0.000    0.000    0.000    0.000 {built-in method time.strftime}
#         4    0.000    0.000    0.000    0.000 __init__.py:799(acquire)
#        67    0.000    0.000    0.000    0.000 realtime_process.py:243(__init__)
#         2    0.000    0.000    0.000    0.000 common.py:164(is_int_or_datetime_dtype)
#         3    0.000    0.000    0.000    0.000 __init__.py:379(usesTime)
#         1    0.000    0.000    0.000    0.000 posixpath.py:115(splitext)
#         1    0.000    0.000    0.000    0.000 __init__.py:118(getLevelName)
#         1    0.000    0.000    0.000    0.000 __init__.py:1515(isEnabledFor)
#         1    0.000    0.000    0.000    0.000 nanops.py:152(_get_fill_value)
#         1    0.000    0.000    0.000    0.000 generic.py:1477(_clear_item_cache)
#         3    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 base.py:3424(_maybe_update_attributes)
#         1    0.000    0.000    0.000    0.000 common.py:315(is_complex_dtype)
#         3    0.000    0.000    0.000    0.000 __init__.py:321(getMessage)
#         1    0.000    0.000    0.000    0.000 genericpath.py:111(_splitext)
#         4    0.000    0.000    0.000    0.000 {method 'write' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:252(_is_owned)
#         1    0.000    0.000    0.000    0.000 internals.py:4555(_extend_blocks)
#         4    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 common.py:153(is_integer_dtype)
#         1    0.000    0.000    0.000    0.000 threading.py:249(_acquire_restore)
#         2    0.000    0.000    0.000    0.000 base.py:590(_coerce_to_ndarray)
#         3    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {pandas.lib.is_lexsorted}
#         1    0.000    0.000    0.000    0.000 posixpath.py:50(normcase)
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 base.py:497(__array__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1501(getEffectiveLevel)
#         1    0.000    0.000    0.000    0.000 {method 'tell' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         3    0.000    0.000    0.000    0.000 __init__.py:695(filter)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:246(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:1224(current_thread)
#         1    0.000    0.000    0.000    0.000 internals.py:4543(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 posixpath.py:39(_get_sep)
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 threading.py:1074(name)
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 codecs.py:213(setstate)

# %%
p.print_callees('EEGDataStream.__call__')
# Out:
#    Random listing order was used
#    List reduced from 642 to 1 due to restriction <'EEGDataStream.__call__'>
#
# Function                                    called...
#                                                 ncalls  tottime  cumtime
# nspike_data.py:468(EEGDataStream.__call__)  ->       1    0.000    0.000  base.py:497(Float64Index.__array__)
#                                                      1    0.000    0.000  base.py:501(Float64Index.__array_wrap__)
#                                                      1    0.000    0.001  base.py:897(Float64Index.argmin)
#                                                 809815    3.385    4.282  base.py:1406(Float64Index.__getitem__)
#                                                      1    0.000    0.001  base.py:3492(Float64Index._evaluate_numeric_binop)
#                                                 449914    1.258    1.258  datatypes.py:19(LFPPoint.__init__)
#                                                 179950    0.537   18.754  generic.py:2910(DataFrame.values)

# %%
prof_dir2 = '/home/daliu/output/timing3/'
filename2 = 'test_animal.01.pstats'
p2 = pstats.Stats(os.path.join(prof_dir2, filename2))
p2.sort_stats('cumtime')
p2.strip_dirs()
p2.print_stats(20)
# Out:
# Fri May 26 20:26:42 2017    /home/daliu/output/timing3/test_animal.01.pstats
#
#          10637976 function calls (10638041 primitive calls) in 51.890 seconds
#
#    Random listing order was used
#    List reduced from 642 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000  125.231  125.231 realtime_process.py:121(SimulatorProcess.outer)
#         1    0.000    0.000  125.231  125.231 simulator_process.py:90(SimulatorProcess.main_loop)
#    452009    2.701    0.000   49.803    0.000 sim_databuffer.py:22(SimDataBuffer.__call__)
#    449915   12.447    0.000   32.478    0.000 nspike_data.py:468(EEGDataStream.__call__)
#    181350    0.393    0.000   16.203    0.000 generic.py:2910(DataFrame.values)
#    181350    1.449    0.000   15.809    0.000 generic.py:2868(DataFrame.as_matrix)
#      2095    0.016    0.000   12.287    0.006 nspike_data.py:975(PosMatDataStream.__call__)
#       700    0.190    0.000   12.254    0.018 nspike_data.py:920(PosMatData.__call__)
#    904084    4.456    0.000   10.229    0.000 threading.py:533(Event.wait)
#    181350    1.044    0.000   10.121    0.000 internals.py:3391(BlockManager.as_matrix)
#     14658    0.235    0.000    6.738    0.000 series.py:600(Series.__getitem__)
#     12564    0.106    0.000    5.975    0.000 multi.py:681(MultiIndex.get_value)
#      4188    0.221    0.000    5.409    0.001 multi.py:689(_try_mi)
#    183442    0.414    0.000    4.587    0.000 internals.py:154(FloatBlock.get_values)
#    181361    1.793    0.000    4.540    0.000 internals.py:2829(BlockManager._is_single_block)
#    182051    0.612    0.000    4.257    0.000 generic.py:2795(DataFrame._consolidate_inplace)
#    184899    0.857    0.000    4.134    0.000 common.py:54(is_object_dtype)
#    182751    0.939    0.000    3.649    0.000 generic.py:2785(DataFrame._protect_consolidate)
#      2099    0.098    0.000    3.186    0.002 frame.py:2035(DataFrame.__getitem__)
# 190075/190083    2.271    0.000    3.136    0.000 common.py:357(_get_dtype_type)

# %%
prof_dir3 = '/home/daliu/output/timing4/'
filename3 = 'test_animal.01.pstats'
p3 = pstats.Stats(os.path.join(prof_dir3, filename3))
p3.sort_stats('cumtime')
p3.strip_dirs()
p3.print_stats(20)
# Out:
# Fri May 26 21:04:19 2017    /home/daliu/output/timing4/test_animal.01.pstats
#
#          10637976 function calls (10638041 primitive calls) in 49.894 seconds
#
#    Random listing order was used
#    List reduced from 642 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000  118.002  118.002 realtime_process.py:121(SimulatorProcess.outer)
#         1    0.000    0.000  118.002  118.002 simulator_process.py:90(SimulatorProcess.main_loop)
#    452009    4.077    0.000   46.285    0.000 sim_databuffer.py:22(SimDataBuffer.__call__)
#    449915    9.237    0.000   27.594    0.000 nspike_data.py:468(EEGDataStream.__call__)
#    181350    0.379    0.000   15.362    0.000 generic.py:2910(DataFrame.values)
#    181350    1.117    0.000   14.983    0.000 generic.py:2868(DataFrame.as_matrix)
#    904084    5.270    0.000   12.346    0.000 threading.py:533(Event.wait)
#      2095    0.015    0.000   12.047    0.006 nspike_data.py:976(PosMatDataStream.__call__)
#       700    0.196    0.000   12.011    0.017 nspike_data.py:921(PosMatData.__call__)
#    181350    0.917    0.000    9.902    0.000 internals.py:3391(BlockManager.as_matrix)
#     14658    0.184    0.000    6.174    0.000 series.py:600(Series.__getitem__)
#     12564    0.214    0.000    5.526    0.000 multi.py:681(MultiIndex.get_value)
#      4188    0.203    0.000    4.864    0.001 multi.py:689(_try_mi)
#    181361    1.819    0.000    4.767    0.000 internals.py:2829(BlockManager._is_single_block)
#    183442    0.458    0.000    4.158    0.000 internals.py:154(FloatBlock.get_values)
#    182051    0.598    0.000    4.005    0.000 generic.py:2795(DataFrame._consolidate_inplace)
#    904086    2.724    0.000    3.953    0.000 threading.py:242(Condition.__exit__)
#    184899    0.502    0.000    3.715    0.000 common.py:54(is_object_dtype)
#    182751    0.971    0.000    3.425    0.000 generic.py:2785(DataFrame._protect_consolidate)
#      2099    0.065    0.000    3.259    0.002 frame.py:2035(DataFrame.__getitem__)

# %%
p3.print_callers('EEGDataStream.__call__')
# Out:
#    Random listing order was used
#    List reduced from 642 to 1 due to restriction <'EEGDataStream.__call__'>
#
# Function                                    was called by...
#                                                 ncalls  tottime  cumtime
# nspike_data.py:468(EEGDataStream.__call__)  <-
