# %%
import pstats
import os.path

# %%
prof_dir = '/home/daliu/output/'
filename = 'test_animal01pstats'
p = pstats.Stats(os.path.join(prof_dir, filename))

# %%
p.sort_stats('cumtime')
p.strip_dirs()
p.print_stats()
# Out:
# Thu May 25 19:53:58 2017    /home/daliu/output/test_animal01pstats
#
#          10919099 function calls (10919164 primitive calls) in 22.004 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   39.734   39.734 realtime_process.py:121(SimulatorProcess.outer)
#         1    0.000    0.000   39.734   39.734 simulator_process.py:90(SimulatorProcess.main_loop)
#    452009    1.180    0.000   22.198    0.000 sim_databuffer.py:22(SimDataBuffer.__call__)
#    449915    3.921    0.000   16.179    0.000 nspike_data.py:632(EEGDataStream.__call__)
#     11248    0.140    0.000   10.173    0.001 nspike_data.py:491(EEGData.__call__)
#     22495    0.089    0.000    9.905    0.000 indexing.py:1302(_iLocIndexer.__getitem__)
#     22495    0.111    0.000    9.768    0.000 indexing.py:1599(_iLocIndexer._getitem_axis)
# ...
